# %% [markdown]
# <a href="https://colab.research.google.com/github/Harini162006/harini-codebooster-2026/blob/main/miniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("student_performance.csv")

# %%
print("Total Students")
print(df.shape[0])
print("Total Columns")
print(df.shape[1])
print("Departments")
depts=df['department'].unique()
print(len(depts))
# Out:
# Total Students
# 30
# Total Columns
# 13
# Departments
# 4

# %%
print(df['department'].value_counts())
# Out:
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print("Highest Math Score: ",df.math_score.max())
print("Lowest Math Score: ",df.math_score.min())
print("Average Math Score: ", df.math_score.mean().round(2))
print(f"Average Programming Score: {df.programming_score.mean():.2f}")
print("Average Attendance: ", df.attendance_percentage.mean().round(2), "%")
# Out:
# Highest Math Score:  95
# Lowest Math Score:  56
# Average Math Score:  76.07
# Average Programming Score: 67.60
# Average Attendance:  84.5 %

# %%
df['total_score']=df['english_score']+df['programming_score']+df['science_score']+df['math_score']
print("Gender-wise average scores")
gender_score=df.groupby('gender')['total_score'].mean().round(2)
print(gender_score)
# Out:
# Gender-wise average scores
# gender
# Female    310.67
# Male      280.67
# Name: total_score, dtype: float64

# %%
df.sort_values('total_score',ascending=False).head(5)
# Out:
#     student_id            name  age  gender        department  semester  \
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 21        1022     Tanvi Mehta   19  Female  Computer Science         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 9           95             89             90                 97
# 21          93             90             88                 96
# 29          91             93             87                 94
# 4           92             88             81                 95
# 7           88             91             84                 93
#
#     attendance_percentage     city  admission_year  total_score
# 9                      98  Kolkata            2023          371
# ...

# %%
print("\n")
low_att=df[df['attendance_percentage']<75][['name','department','attendance_percentage']]
if len(low_att)>0:
  print(low_att.to_string(index=False))
else:
  print("All students have attendance above 75%")

print("Report complete")
# Out:
#          name  department  attendance_percentage
#   Meera Joshi Electronics                     72
#  Rahul Mishra  Mechanical                     68
#  Manoj Pandey       Civil                     65
# Harish Pillai Electronics                     74
#  Sanjay Dubey       Civil                     70
# Sunita Pillai       Civil                     73
# Report complete
